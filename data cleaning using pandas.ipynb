# %%
import pandas as pd

# %%
df = pd.read_csv('cricket.csv')

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1  PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50    0    4s  6s
# 0  58.60   29  13  7.0  626+   6
# 1  64.38    5   4  NaN   123  23
# 2  55.68    5   4  2.0   186   5
# 3  54.48    7  11  1.0  246+  11
# 4  56.00   10   5  2.0  104+   1

# %%
#renaming the columns

# %%
df = df.rename(columns = {'Mat':'matches','NO':'not_out','HS':'highest_inns_score','BF':'balls_faced','SR':'batting_strike_rate'})

# %%
df.head()
# Out:
#              Player       Span  matches  Inns  not_out  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1  PHKD Mendis (SL)  2022-2025       12    21        2  1184
# 2    AC Voges (AUS)  2015-2016       20    31        7  1485
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256
# 4   GA Headley (WI)  1930-1954       22    40        4  2190
#
#   highest_inns_score    Ave balls_faced  batting_strike_rate  100  50    0  \
# 0                334  99.94       9800+                58.60   29  13  7.0
# 1               182*  62.31        1839                64.38    5   4  NaN
# 2               269*  61.87        2667                55.68    5   4  2.0
# 3                274  60.97       1707+                54.48    7  11  1.0
# 4               270*  60.83        416+                56.00   10   5  2.0
#
#      4s  6s
# 0  626+   6
# 1   123  23
# 2   186   5
# 3  246+  11
# 4  104+   1

# %%
#check the null values

# %%
df.isnull().sum()
# Out:
# Player                 0
# Span                   0
# matches                0
# Inns                   0
# not_out                0
# Runs                   0
# highest_inns_score     0
# Ave                    0
# balls_faced            2
# batting_strike_rate    0
# 100                    0
# 50                     0
# 0                      1
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df[df['balls_faced'].isna() == 1]
# Out:
#              Player       Span  matches  Inns  not_out  Runs  \
# 8    ED Weekes (WI)  1948-1958       48    81        5  4455
# 15  CL Walcott (WI)  1948-1960       44    74        7  3798
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50    0  \
# 8                 207  58.61         NaN                  0.0   15  19  6.0
# 15                220  56.68         NaN                  0.0   15  14  1.0
#
#       4s  6s
# 8   258+   2
# 15  107+  11

# %%
df['balls_faced'] = df['balls_faced'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span  matches  Inns  not_out  Runs  \
# 15  CL Walcott (WI)  1948-1960       44    74        7  3798
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50    0  \
# 15                220  56.68           0                  0.0   15  14  1.0
#
#       4s  6s
# 15  107+  11

# %%
#drop duplicate

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64     True
# 65     True
# 66     True
# 67     True
# 68     True
# Length: 69, dtype: bool

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                Player       Span  matches  Inns  not_out  Runs  \
# 62  IVA Richards (WI)  1974-1991      121   182       12  8540
# 63  IVA Richards (WI)  1974-1991      121   182       12  8540
# 64    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 65    B Mitchell (SA)  1929-1949       42    80        9  3471
# 66    B Mitchell (SA)  1929-1949       42    80        9  3471
# 67    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 68    SJ McCabe (AUS)  1930-1938       39    62        5  2748
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50     0  \
# 62                291  50.23       9613+                69.77   24  45  10.0
# 63                291  50.23       9613+                69.77   24  45  10.0
# 64                232  48.21       3217+                60.02    6  13   4.0
# 65               189*  48.88        158+                29.11    8  21   3.0
# 66               189*  48.88        158+                29.11    8  21   3.0
# 67                232  48.21       3217+                60.02    6  13   4.0
# 68                232  48.21       3217+                60.02    6  13   4.0
#
#       4s  6s
# 62  952+  84
# 63  952+  84
# 64  241+  5+
# 65   41+   1
# 66   41+   1
# 67  241+  5+
# 68  241+  5+

# %%
df[df['Player'].isin(['IVA Richards (WI)','IVA Richards (WI)','SJ McCabe (AUS)','B Mitchell (SA)','B Mitchell (SA)','SJ McCabe (AUS)','SJ McCabe (AUS)'])]
# Out:
#                Player       Span  matches  Inns  not_out  Runs  \
# 43  IVA Richards (WI)  1974-1991      121   182       12  8540
# 53    B Mitchell (SA)  1929-1949       42    80        9  3471
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 62  IVA Richards (WI)  1974-1991      121   182       12  8540
# 63  IVA Richards (WI)  1974-1991      121   182       12  8540
# 64    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 65    B Mitchell (SA)  1929-1949       42    80        9  3471
# 66    B Mitchell (SA)  1929-1949       42    80        9  3471
# 67    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 68    SJ McCabe (AUS)  1930-1938       39    62        5  2748
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50     0  \
# 43                291  50.23       9613+                69.77   24  45  10.0
# 53               189*  48.88        158+                29.11    8  21   3.0
# 60                232  48.21       3217+                60.02    6  13   4.0
# 62                291  50.23       9613+                69.77   24  45  10.0
# 63                291  50.23       9613+                69.77   24  45  10.0
# 64                232  48.21       3217+                60.02    6  13   4.0
# 65               189*  48.88        158+                29.11    8  21   3.0
# 66               189*  48.88        158+                29.11    8  21   3.0
# 67                232  48.21       3217+                60.02    6  13   4.0
# 68                232  48.21       3217+                60.02    6  13   4.0
#
#       4s  6s
# 43  952+  84
# 53   41+   1
# 60  241+  5+
# 62  952+  84
# 63  952+  84
# 64  241+  5+
# 65   41+   1
# 66   41+   1
# 67  241+  5+
# 68  241+  5+

# %%
df.drop_duplicates()
# Out:
#                Player       Span  matches  Inns  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1    PHKD Mendis (SL)  2022-2025       12    21        2  1184
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256
# 4     GA Headley (WI)  1930-1954       22    40        4  2190
# ..                ...        ...      ...   ...      ...   ...
# 57   KD Walters (AUS)  1965-1981       74   125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014      117   205       13  9265
# 59  WH Ponsford (AUS)  1924-1934       29    48        4  2122
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 61   DR Jardine (ENG)  1928-1934       22    33        6  1296
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50     0  \
# 0                 334  99.94       9800+                58.60   29  13   7.0
# 1                182*  62.31        1839                64.38    5   4   NaN
# 2                269*  61.87        2667                55.68    5   4   2.0
# 3                 274  60.97       1707+                54.48    7  11   1.0
# 4                270*  60.83        416+                56.00   10   5   2.0
# ..                ...    ...         ...                  ...  ...  ..   ...
# 57                250  48.26       8662+                49.16   15  33   4.0
# 58                277  48.25       15525                59.67   27  38  11.0
# 59                266  48.22       3118+                44.77    7   6   1.0
# 60                232  48.21       3217+                60.02    6  13   4.0
# 61                127  48.00       2110+                25.59    1  10   2.0
#
#       4s  6s
# 0   626+   6
# 1    123  23
# 2    186   5
# 3   246+  11
# 4   104+   1
# ..   ...  ..
# 57  525+  23
# 58  1165  24
# 59  119+   0
# 60  241+  5+
# 61   53+   0
#
# [62 rows x 15 columns]

# %%
#split up span into start and end date

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2025
# 2     2016
# 3     1970
# 4     1954
#       ...
# 64    1938
# 65    1949
# 66    1949
# 67    1938
# 68    1938
# Name: Span, Length: 69, dtype: object

# %%
df['rookie_year']= df['Span'].str.split(pat = '-').str[0]

# %%
df['final_year']= df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#               Player       Span  matches  Inns  not_out  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1   PHKD Mendis (SL)  2022-2025       12    21        2  1184
# 2     AC Voges (AUS)  2015-2016       20    31        7  1485
# 3    RG Pollock (SA)  1963-1970       23    41        4  2256
# 4    GA Headley (WI)  1930-1954       22    40        4  2190
# ..               ...        ...      ...   ...      ...   ...
# 64   SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 65   B Mitchell (SA)  1929-1949       42    80        9  3471
# 66   B Mitchell (SA)  1929-1949       42    80        9  3471
# 67   SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 68   SJ McCabe (AUS)  1930-1938       39    62        5  2748
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50    0  \
# 0                 334  99.94       9800+                58.60   29  13  7.0
# 1                182*  62.31        1839                64.38    5   4  NaN
# 2                269*  61.87        2667                55.68    5   4  2.0
# 3                 274  60.97       1707+                54.48    7  11  1.0
# 4                270*  60.83        416+                56.00   10   5  2.0
# ..                ...    ...         ...                  ...  ...  ..  ...
# 64                232  48.21       3217+                60.02    6  13  4.0
# 65               189*  48.88        158+                29.11    8  21  3.0
# 66               189*  48.88        158+                29.11    8  21  3.0
# 67                232  48.21       3217+                60.02    6  13  4.0
# 68                232  48.21       3217+                60.02    6  13  4.0
#
#       4s  6s rookie_year final_year
# 0   626+   6        1928       1948
# 1    123  23        2022       2025
# 2    186   5        2015       2016
# 3   246+  11        1963       1970
# 4   104+   1        1930       1954
# ..   ...  ..         ...        ...
# 64  241+  5+        1930       1938
# 65   41+   1        1929       1949
# 66   41+   1        1929       1949
# 67  241+  5+        1930       1938
# 68  241+  5+        1930       1938
#
# [69 rows x 17 columns]

# %%
#drop span column

# %%
df = df.drop(['Span'],axis = 1)

# %%
df
# Out:
#               Player  matches  Inns  not_out  Runs highest_inns_score    Ave  \
# 0   DG Bradman (AUS)       52    80       10  6996                334  99.94
# 1   PHKD Mendis (SL)       12    21        2  1184               182*  62.31
# 2     AC Voges (AUS)       20    31        7  1485               269*  61.87
# 3    RG Pollock (SA)       23    41        4  2256                274  60.97
# 4    GA Headley (WI)       22    40        4  2190               270*  60.83
# ..               ...      ...   ...      ...   ...                ...    ...
# 64   SJ McCabe (AUS)       39    62        5  2748                232  48.21
# 65   B Mitchell (SA)       42    80        9  3471               189*  48.88
# 66   B Mitchell (SA)       42    80        9  3471               189*  48.88
# 67   SJ McCabe (AUS)       39    62        5  2748                232  48.21
# 68   SJ McCabe (AUS)       39    62        5  2748                232  48.21
#
#    balls_faced  batting_strike_rate  100  50    0    4s  6s rookie_year  \
# 0        9800+                58.60   29  13  7.0  626+   6        1928
# 1         1839                64.38    5   4  NaN   123  23        2022
# 2         2667                55.68    5   4  2.0   186   5        2015
# 3        1707+                54.48    7  11  1.0  246+  11        1963
# 4         416+                56.00   10   5  2.0  104+   1        1930
# ..         ...                  ...  ...  ..  ...   ...  ..         ...
# 64       3217+                60.02    6  13  4.0  241+  5+        1930
# 65        158+                29.11    8  21  3.0   41+   1        1929
# 66        158+                29.11    8  21  3.0   41+   1        1929
# 67       3217+                60.02    6  13  4.0  241+  5+        1930
# 68       3217+                60.02    6  13  4.0  241+  5+        1930
#
#    final_year
# 0        1948
# 1        2025
# 2        2016
# 3        1970
# 4        1954
# ..        ...
# 64       1938
# 65       1949
# 66       1949
# 67       1938
# 68       1938
#
# [69 rows x 16 columns]

# %%
#split up the country from the player

# %%
df['Player'].str.split(pat = '(').str[1]
# Out:
# 0     AUS)
# 1      SL)
# 2     AUS)
# 3      SA)
# 4      WI)
#       ...
# 64    AUS)
# 65     SA)
# 66     SA)
# 67    AUS)
# 68    AUS)
# Name: Player, Length: 69, dtype: object

# %%
df['country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['country'] = df['country'].str.split(pat = ')').str[0]

# %%
df['country']
# Out:
# 0     AUS
# 1      SL
# 2     AUS
# 3      SA
# 4      WI
#      ...
# 64    AUS
# 65     SA
# 66     SA
# 67    AUS
# 68    AUS
# Name: country, Length: 69, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df
# Out:
#           Player  matches  Inns  not_out  Runs highest_inns_score    Ave  \
# 0    DG Bradman        52    80       10  6996                334  99.94
# 1   PHKD Mendis        12    21        2  1184               182*  62.31
# 2      AC Voges        20    31        7  1485               269*  61.87
# 3    RG Pollock        23    41        4  2256                274  60.97
# 4    GA Headley        22    40        4  2190               270*  60.83
# ..           ...      ...   ...      ...   ...                ...    ...
# 64    SJ McCabe        39    62        5  2748                232  48.21
# 65   B Mitchell        42    80        9  3471               189*  48.88
# 66   B Mitchell        42    80        9  3471               189*  48.88
# 67    SJ McCabe        39    62        5  2748                232  48.21
# 68    SJ McCabe        39    62        5  2748                232  48.21
#
#    balls_faced  batting_strike_rate  100  50    0    4s  6s rookie_year  \
# 0        9800+                58.60   29  13  7.0  626+   6        1928
# 1         1839                64.38    5   4  NaN   123  23        2022
# 2         2667                55.68    5   4  2.0   186   5        2015
# 3        1707+                54.48    7  11  1.0  246+  11        1963
# 4         416+                56.00   10   5  2.0  104+   1        1930
# ..         ...                  ...  ...  ..  ...   ...  ..         ...
# 64       3217+                60.02    6  13  4.0  241+  5+        1930
# 65        158+                29.11    8  21  3.0   41+   1        1929
# 66        158+                29.11    8  21  3.0   41+   1        1929
# 67       3217+                60.02    6  13  4.0  241+  5+        1930
# 68       3217+                60.02    6  13  4.0  241+  5+        1930
#
#    final_year country
# 0        1948     AUS
# 1        2025      SL
# 2        2016     AUS
# 3        1970      SA
# 4        1954      WI
# ..        ...     ...
# 64       1938     AUS
# 65       1949      SA
# 66       1949      SA
# 67       1938     AUS
# 68       1938     AUS
#
# [69 rows x 17 columns]

# %%
#change datatype

# %%
df.dtypes
# Out:
# Player                  object
# matches                  int64
# Inns                     int64
# not_out                  int64
# Runs                     int64
# highest_inns_score      object
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# rookie_year             object
# final_year              object
# country                 object
# dtype: object

# %%
df['highest_inns_score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 64    232
# 65    189
# 66    189
# 67    232
# 68    232
# Name: highest_inns_score, Length: 69, dtype: object

# %%
df['highest_inns_score'] = df['highest_inns_score'].str.split(pat = '*').str[0]

# %%
df
# Out:
#           Player  matches  Inns  not_out  Runs highest_inns_score    Ave  \
# 0    DG Bradman        52    80       10  6996                334  99.94
# 1   PHKD Mendis        12    21        2  1184                182  62.31
# 2      AC Voges        20    31        7  1485                269  61.87
# 3    RG Pollock        23    41        4  2256                274  60.97
# 4    GA Headley        22    40        4  2190                270  60.83
# ..           ...      ...   ...      ...   ...                ...    ...
# 64    SJ McCabe        39    62        5  2748                232  48.21
# 65   B Mitchell        42    80        9  3471                189  48.88
# 66   B Mitchell        42    80        9  3471                189  48.88
# 67    SJ McCabe        39    62        5  2748                232  48.21
# 68    SJ McCabe        39    62        5  2748                232  48.21
#
#    balls_faced  batting_strike_rate  100  50    0    4s  6s rookie_year  \
# 0        9800+                58.60   29  13  7.0  626+   6        1928
# 1         1839                64.38    5   4  NaN   123  23        2022
# 2         2667                55.68    5   4  2.0   186   5        2015
# 3        1707+                54.48    7  11  1.0  246+  11        1963
# 4         416+                56.00   10   5  2.0  104+   1        1930
# ..         ...                  ...  ...  ..  ...   ...  ..         ...
# 64       3217+                60.02    6  13  4.0  241+  5+        1930
# 65        158+                29.11    8  21  3.0   41+   1        1929
# 66        158+                29.11    8  21  3.0   41+   1        1929
# 67       3217+                60.02    6  13  4.0  241+  5+        1930
# 68       3217+                60.02    6  13  4.0  241+  5+        1930
#
#    final_year country
# 0        1948     AUS
# 1        2025      SL
# 2        2016     AUS
# 3        1970      SA
# 4        1954      WI
# ..        ...     ...
# 64       1938     AUS
# 65       1949      SA
# 66       1949      SA
# 67       1938     AUS
# 68       1938     AUS
#
# [69 rows x 17 columns]

# %%
df['highest_inns_score'] = df['highest_inns_score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# matches                  int64
# Inns                     int64
# not_out                  int64
# Runs                     int64
# highest_inns_score       int64
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# rookie_year             object
# final_year              object
# country                 object
# dtype: object

# %%
df = df.astype({'rookie_year':'int','final_year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# matches                  int64
# Inns                     int64
# not_out                  int64
# Runs                     int64
# highest_inns_score       int64
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# rookie_year              int64
# final_year               int64
# country                 object
# dtype: object

# %%
df['matches'] = df['matches'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# matches                  int64
# Inns                     int64
# not_out                  int64
# Runs                     int64
# highest_inns_score       int64
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# rookie_year              int64
# final_year               int64
# country                 object
# dtype: object

# %%
df['career_length'] = df['final_year'] - df['rookie_year']

# %%
df
# Out:
#           Player  matches  Inns  not_out  Runs  highest_inns_score    Ave  \
# 0    DG Bradman        52    80       10  6996                 334  99.94
# 1   PHKD Mendis        12    21        2  1184                 182  62.31
# 2      AC Voges        20    31        7  1485                 269  61.87
# 3    RG Pollock        23    41        4  2256                 274  60.97
# 4    GA Headley        22    40        4  2190                 270  60.83
# ..           ...      ...   ...      ...   ...                 ...    ...
# 64    SJ McCabe        39    62        5  2748                 232  48.21
# 65   B Mitchell        42    80        9  3471                 189  48.88
# 66   B Mitchell        42    80        9  3471                 189  48.88
# 67    SJ McCabe        39    62        5  2748                 232  48.21
# 68    SJ McCabe        39    62        5  2748                 232  48.21
#
#    balls_faced  batting_strike_rate  100  50    0    4s  6s  rookie_year  \
# 0        9800+                58.60   29  13  7.0  626+   6         1928
# 1         1839                64.38    5   4  NaN   123  23         2022
# 2         2667                55.68    5   4  2.0   186   5         2015
# 3        1707+                54.48    7  11  1.0  246+  11         1963
# 4         416+                56.00   10   5  2.0  104+   1         1930
# ..         ...                  ...  ...  ..  ...   ...  ..          ...
# 64       3217+                60.02    6  13  4.0  241+  5+         1930
# 65        158+                29.11    8  21  3.0   41+   1         1929
# 66        158+                29.11    8  21  3.0   41+   1         1929
# 67       3217+                60.02    6  13  4.0  241+  5+         1930
# 68       3217+                60.02    6  13  4.0  241+  5+         1930
#
#     final_year country  career_length
# 0         1948     AUS             20
# 1         2025      SL              3
# 2         2016     AUS              1
# 3         1970      SA              7
# 4         1954      WI             24
# ..         ...     ...            ...
# 64        1938     AUS              8
# 65        1949      SA             20
# 66        1949      SA             20
# 67        1938     AUS              8
# 68        1938     AUS              8
#
# [69 rows x 18 columns]

# %%
#average career length

# %%
df['career_length'].mean()
# Out:
# 13.072463768115941

# %%
#avg botting_strike_rate for ciicket player over 10 years

# %%
df[df['career_length'] > 10]['batting_strike_rate'].mean()
# Out:
# 47.94127659574469
